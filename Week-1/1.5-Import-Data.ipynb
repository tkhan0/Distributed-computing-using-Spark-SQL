# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px; height: 163px">
# </div>

# %% [markdown]
# # 1.5 Import Data
#
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) In this notebook you:<br>
# * Get data into Databricks
# * Query Data

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Getting Data into Databricks
#
# There are a number of ways of getting data into Databricks.  In this lesson, you'll upload a flat CSV file into Databricks before creating a table and querying it.

# %% [markdown]
# ## Download Dataset
#
# Download a subset of the Data SF's Fire Department Calls for Service [here](https://s3-us-west-2.amazonaws.com/davis-dsv1071/data/fire-calls/fire-calls-truncated-comma.csv). This dataset is about 85 MB.
#
# The entire dataset is ~1.7GB, and can be found on [Data SF](https://data.sfgov.org/Public-Safety/Fire-Department-Calls-for-Service/nuek-vuh3/data)

# %% [markdown]
# -sandbox
# ## Import Dataset
#
# **NOTE**: You will need to have a cluster running to add data.<br><br>
#
# 1. Navigate to the `Data` tab on the left hand panel of your Databricks workspace
# <div><br><img src="https://files.training.databricks.com/images/eLearning/ucdavis/importdata1.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px; box-shadow: 5px 5px 5px #aaa; margin: 20px"/></div>
# 2. Select `Add Data`
# <div><br><img src="https://files.training.databricks.com/images/eLearning/ucdavis/importdata2.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px; box-shadow: 5px 5px 5px #aaa; margin: 20px"/></div>
# 3. Click `Browse` and select the file.  If you haven't already downloaded it, you can find it [here](https://s3-us-west-2.amazonaws.com/davis-dsv1071/data/fire-calls/fire-calls-truncated-comma.csv)
# <div><br><img src="https://files.training.databricks.com/images/eLearning/ucdavis/importdata3.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px; box-shadow: 5px 5px 5px #aaa; margin: 20px"/></div>
# 4. Click `Create Table with UI`
# <div><br><img src="https://files.training.databricks.com/images/eLearning/ucdavis/importdata4.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px; box-shadow: 5px 5px 5px #aaa; margin: 20px"/></div>
# 5. Select the cluster you have running.  If you don't have a running cluster, create one in the `Clusters` tab.
# <div><br><img src="https://files.training.databricks.com/images/eLearning/ucdavis/importdata5.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px; box-shadow: 5px 5px 5px #aaa; margin: 20px"/></div>
# 6. Name the table `firecallsuploaded`
# 7. Select `First row is header`
# 8. Select `Infer schema`
# 9. Select `Create Table`
# <div><br><img src="https://files.training.databricks.com/images/eLearning/ucdavis/importdata6.png" style="border: 1px solid #aaa; border-radius: 10px 10px 10px 10px; box-shadow: 5px 5px 5px #aaa; margin: 20px"/></div>
# 10. Continue on in the rest of this notebook.

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Querying Data
#
# Now you can access the file you uploaded.

# %% [markdown]
# Take a look at the first few lines of the data.

# %%
# %sql
SELECT * FROM fire_calls LIMIT 10
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Look at the number of emergency calls by call type.

# %%
# %sql
SELECT `Call Type`, count(1) as count 
FROM fire_calls 
GROUP BY `Call Type` 
ORDER BY count DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# Now look at calls by neighborhood.

# %%
# %sql
SELECT `Neighborhooods - Analysis Boundaries` as neighborhood, count(1) as count 
FROM fire_calls 
GROUP BY `Neighborhooods - Analysis Boundaries` 
ORDER BY count DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
